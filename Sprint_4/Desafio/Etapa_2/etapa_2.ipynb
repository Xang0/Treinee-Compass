# %% [markdown]
# # Etapa 2
#
# A partir do arquivo que está dentro do S3, crie um dataframe com pandas ou polars e execute as análises escolhidas.

# %%
# Importação das bibliotecas necessárias
import pandas as pd
import boto3
from botocore.exceptions import NoCredentialsError, ClientError

# %%
# Definição das função para upload e download
# Função de download
def upload_to_s3(local_file, bucket_name, s3_key):
    try:
        # Create an S3 client
        s3 = boto3.client('s3')
        
        # Upload the file
        s3.upload_file(
            Filename=local_file,
            Bucket=bucket_name,
            Key=s3_key,
            ExtraArgs={'ACL': 'public-read'}  # Optional: Set object ACL
        )
        print(f"File '{local_file}' uploaded to '{s3_key}' in bucket '{bucket_name}'.")
        return True
    except NoCredentialsError:
        print("Credentials not available. Check AWS configuration.")
        return False
    except ClientError as e:
        print(f"An error occurred: {e.response['Error']['Message']}")
        return False


# Função de upload
def download_from_s3(bucket_name, s3_key, local_file_path):
    try:
        # Cria um cliente S3
        s3 = boto3.client('s3')
        
        # Faz o download do arquivo
        s3.download_file(
            Bucket=bucket_name,
            Key=s3_key,
            Filename=local_file_path
        )
        print(f"File '{s3_key}' downloaded from bucket '{bucket_name}' to '{local_file_path}'.")
        return True
    except NoCredentialsError:
        print("Credentials not available. Check AWS configuration.")
        return False
    except ClientError as e:
        print(f"Error: {e.response['Error']['Message']}")
        return False

# %%
# Importando o arquivo
download_from_s3('desafio-compass-pb', 'data/arp-2022-2023.csv', 'arp-2022-2023.csv')
arquivo = pd.read_csv('arp-2022-2023.csv')
arquivo.drop_duplicates()
# Out:
# File 'data/arp-2022-2023.csv' downloaded from bucket 'desafio-compass-pb' to 'arp-2022-2023.csv'.
#      pregão   ano    número             cpf_cnpj  \
# 0   17/2022  2022   89/2022   15.153.524/0001-90
# 1   17/2022  2022   93/2022   41.278.336/0001-06
# 2   17/2022  2022   92/2022   28.591.670/0001-49
# 3   17/2022  2022   95/2022   03.217.016/0001-49
# 4   17/2022  2022   86/2022   07.147.983/0001-32
# 5   17/2022  2022   94/2022   83.764.316/0001-87
# 6   17/2022  2022   88/2022   11.258.338/0001-64
# 7   17/2022  2022   87/2022   11.163.447/0001-06
# 8   17/2022  2022   90/2022   18.158.411/0001-75
# 9   42/2022  2022   34/2023   03.541.496/0001-07
# 10  42/2022  2022   31/2023   11.888.791/0001-54
# 11  42/2022  2022   29/2023   08.778.201/0001-26
# 12  42/2022  2022   28/2023   01.399.246/0001-40
# 13  42/2022  2022   30/2023   10.468.162/0001-02
# 14  42/2022  2022   32/2023   23.312.871/0001-46
# 15  42/2022  2022   35/2023   44.734.671/0001-51
# 16  42/2022  2022   33/2023   29.043.834/0001-66
# 17  39/2022  2022   24/2023   35.534.016/0001-69
# 18  39/2022  2022   19/2023   03.541.496/0001-07
# 19  39/2022  2022   21/2023   08.563.964/0001-50
# 20  39/2022  2022   20/2023   07.296.219/0001-29
# 21  39/2022  2022   25/2023   38.457.380/0001-60
# 22  39/2022  2022   22/2023   28.591.670/0001-49
# 23  39/2022  2022   23/2023   34.577.439/0001-01
# 24  39/2022  2022   21/2023   08.563.964/0001-50
# 25  20/2022  2022  109/2022   46.536.739/0001-13
# 26  20/2022  2022  104/2022   11.195.926/0001-04
# 27  20/2022  2022  105/2022   16.914.974/0001-10
# 28  20/2022  2022  106/2022   34.657.550/0001-08
# 29  20/2022  2022  107/2022   36.327.259/0001-99
# 30  20/2022  2022  108/2022   36.336.388/0001-43
# 31  32/2022  2022   01/2023   07.944.100/0001-15
# 32  32/2022  2022   02/2023   08.347.008/0001-30
# 33  32/2022  2022   03/2023   10.468.162/0001-02
# 34  32/2022  2022   04/2023   19.026.964/0001-37
# 35  32/2022  2022   05/2023   19.785.718/0001-69
# 36  32/2022  2022   06/2023   34.577.439/0001-01
# 37  32/2022  2022   07/2023   40.949.490/0001-91
# 38  32/2022  2022   08/2023   41.391.445/0001-27
# 39  32/2022  2022   09/2023   44.219.136/0001-62
# 40  32/2022  2022   10/2023   45.838.204/0001-34
# 41  06/2023  2023   59/2023   10.468.162/0001-02
# 42  06/2023  2023   60/2023   23.420.875/0001-48
# 43  06/2023  2023   61/2023   34.875.727/0001-34
# 44  06/2023  2023   62/2023   40.274.237/0001-85
#
#                                            fornecedor  \
# 0                                       SANIGRAN LTDA
# 1                     A BZ COMERCIO E SERVICOS EIRELI
# 2              VETSUL COMERCIO DE MEDICAMENTOS EIRELI
# 3                                  RPF COMERCIAL LTDA
# 4              LICITAPREMIUM SERVIÇOS E COMÉRCIO LTDA
# 5   J F ALVES COMERCIO ATACADISTA DE PRODUTOS AGRI...
# 6                        MERCOSUL AGRONEGOCIOS EIRELI
# 7                     TECA TECNOLOGIA E COMERCIO LTDA
# 8      HELO PRODUTOS AGROPECUARIOS E SERVIÇOS LTDA-ME
# 9     LOBATO\nCOMERCIO DE PRODUTOS HOSPITALARES\nLTDA
# 10              DISTRIBUIDORA FLAMED HOSPITALAR\nLTDA
# 11                                    DROGAFONTE LTDA
# 12                GUILBER FARMACEUTICA COMERCIO\nLTDA
# 13                    FARMACEUTICA DISTRIBUIDORA LTDA
# 14  EXEMPLARMED\nCOMERCIO DE PRODUTOS HOSPITALARES...
# 15  A CRISTALIA PRODUTOS QUIMICOS\nFARMACEUTICOS LTDA
# 16           3MED DISTRIBUIDORA DE\nMEDICAMENTOS LTDA
# 17                            RENATO MACHADO PINTO-ME
# 18  CESAR & ROCHA COMERCIO DE\nPRODUTOS AGROPECUAR...
# 19  AGROVET SUL\nSERVICOS E COMERCIO DE EQUIPAMENT...
# 20                             E.R FELIX - PROD AGROP
# 21                            MATOS MEDICAMENTOS LTDA
# 22              VETSUL COMERCIO DE\nMEDICAMENTOS LTDA
# 23                              BRASIL SHOPPING\nLTDA
# 24  AGROVET SUL SERVICOS E COMERCIO DE EQUIPAMENTO...
# 25                  PIXTEC COMERCIO E TECNOLOGIA LTDA
# 26              BERGAMO & CAVALCANTE INFORMATICA LTDA
# 27  INFORTECH COMÉRCIO E SERVIÇOS DE INFORMÁTICA E...
# 28                G C E SILVA COMERCIO DE INFORMATICA
# 29                          E G DE MELO DE SOUZA LTDA
# 30                        REGINA CELIA CUNHA DE SOUSA
# 31                       PROC9 INDÚSTRIA QUIMÍCA LTDA
# 32                             FERMASIL COMERCIO LTDA
# 33                    FARMACEUTICA DISTRIBUIDORA LTDA
# 34                                ILMA CHAVES PEREIRA
# 35  L. N. RODRIGUES DISTRIBUIDORA DE PRODUTOS ORTO...
# 36                               BRASIL SHOPPING LTDA
# 37                             A L F SILVA & CIA LTDA
# 38         EXITO SOLUCOES DE SERVICOS E COMERCIO LTDA
# 39                            ATLAS EQUIPAMENTOS LTDA
# 40  MEDPRIME DISTRIBUIDORA DE MEDICAMENTOS E INSUM...
# 41                    FARMACEUTICA DISTRIBUIDORA LTDA
# 42                M. VALENCIA - PRODUTOS HOSPITALARES
# 43           LOBATO COMERCIO DE PRODUTOS HOSPITALARES
# 44  CLM FARMA COMERCIO E DISTRIBUIDORA DE MEDICAME...
#
#                                       objeto        valor  assinatura  \
# 0                      INSUMOS AGROPECUÁRIOS    R$ 46.418          60
# 1                      INSUMOS AGROPECUÁRIOS   R$ 204.450           0
# 2                      INSUMOS AGROPECUÁRIOS    R$ 44.168          50
# 3                      INSUMOS AGROPECUÁRIOS     R$ 4.735          70
# 4                      INSUMOS AGROPECUÁRIOS    R$ 95.500           0
# 5                      INSUMOS AGROPECUÁRIOS   R$ 558.720           0
# 6                      INSUMOS AGROPECUÁRIOS    R$ 62.500           0
# 7                      INSUMOS AGROPECUÁRIOS   R$ 257.853           0
# 8                      INSUMOS AGROPECUÁRIOS    R$ 39.205           0
# 9                         MEDICAMENTO HUMANO   R$ 196.231          50
# 10                        MEDICAMENTO HUMANO    R$ 13.804           0
# 11                        MEDICAMENTO HUMANO   R$ 106.000           0
# 12                        MEDICAMENTO HUMANO    R$ 10.000           0
# 13                        MEDICAMENTO HUMANO   R$ 294.231          60
# 14                        MEDICAMENTO HUMANO     R$ 4.345           0
# 15                        MEDICAMENTO HUMANO   R$ 232.378           0
# 16                        MEDICAMENTO HUMANO    R$ 32.948          10
# 17                   MEDICAMENTO VETERINÁRIO    R$ 35.310           0
# 18                   MEDICAMENTO VETERINÁRIO   R$ 600.075           0
# 19                   MEDICAMENTO VETERINÁRIO    R$ 54.375           0
# 20                   MEDICAMENTO VETERINÁRIO    R$ 24.150           0
# 21                   MEDICAMENTO VETERINÁRIO     R$ 5.436           0
# 22                   MEDICAMENTO VETERINÁRIO     R$ 5.544           0
# 23                   MEDICAMENTO VETERINÁRIO    R$ 35.935           0
# 24                   MEDICAMENTO VETERINÁRIO    R$ 54.375           0
# 25                PERIFÉRICOS DE INFORMÁTICA    R$ 22.990           0
# 26                PERIFÉRICOS DE INFORMÁTICA   R$ 163.920           0
# 27                PERIFÉRICOS DE INFORMÁTICA    R$ 12.000           0
# 28                PERIFÉRICOS DE INFORMÁTICA     R$ 8.400           0
# 29                PERIFÉRICOS DE INFORMÁTICA     R$ 6.800           0
# 30                PERIFÉRICOS DE INFORMÁTICA       R$ 294           0
# 31  MATERIAL LABORATORIAL E MÉDICO HOSPITLAR    R$ 17.240           0
# 32  MATERIAL LABORATORIAL E MÉDICO HOSPITLAR    R$ 48.170           0
# 33  MATERIAL LABORATORIAL E MÉDICO HOSPITLAR    R$ 13.440           0
# 34  MATERIAL LABORATORIAL E MÉDICO HOSPITLAR   R$ 202.188           0
# 35  MATERIAL LABORATORIAL E MÉDICO HOSPITLAR    R$ 45.378           0
# 36  MATERIAL LABORATORIAL E MÉDICO HOSPITLAR       R$ 940           0
# 37  MATERIAL LABORATORIAL E MÉDICO HOSPITLAR    R$ 17.064           0
# 38  MATERIAL LABORATORIAL E MÉDICO HOSPITLAR    R$ 83.565           0
# 39  MATERIAL LABORATORIAL E MÉDICO HOSPITLAR     R$ 8.844           0
# 40  MATERIAL LABORATORIAL E MÉDICO HOSPITLAR    R$ 14.598           0
# 41                        MEDICAMENTO HUMANO    R$ 29.555           0
# 42                        MEDICAMENTO HUMANO    R$ 27.017          60
# 43                        MEDICAMENTO HUMANO    R$ 85.100          40
# 44                        MEDICAMENTO HUMANO    R$ 38.752          50
#
#     inicio_vigencia   fim_vigencia    Unnamed: 10
# 0        29/08/2022     07/10/2022     07/102023
# 1        21/09/2022     07/10/2022     07/102023
# 2   NÃO CONSTA DATA     07/10/2022     07/102023
# 3        30/08/2022     07/10/2022     07/102023
# 4        29/08/2022     07/10/2022     07/102023
# 5        30/08/2022     07/10/2022     07/102023
# 6        29/08/2022     07/10/2022     07/102023
# 7        30/08/2022     07/10/2022     07/102023
# 8        05/09/2022     07/10/2022     07/102023
# 9        01/03/2023    13/03/2023      13/03/2024
# 10       28/02/2023    13/03/2023      13/03/2024
# 11       28/02/2023    13/03/2023      13/03/2024
# 12       01/03/2023    13/03/2023      13/03/2024
# 13       27/02/2023    13/03/2023      13/03/2024
# 14       01/03/2023    13/03/2023      13/03/2024
# 15       27/02/2023    13/03/2023      13/03/2024
# 16       02/02/2023    13/03/2023      13/03/2024
# 17       07/02/2023     24/02/2023     24/02/2024
# 18       07/02/2023     24/02/2023     24/02/2024
# 19       07/02/2023     24/02/2023     24/02/2024
# 20  NÃO CONSTA DATA     24/02/2023     24/02/2024
# 21       07/02/2023     24/02/2023     24/02/2024
# 22  NÃO CONSTA DATA     24/02/2023     24/02/2024
# 23       07/02/2023     24/02/2023     24/02/2024
# 24       07/02/2023     24/02/2023     24/02/2024
# 25       08/11/2022  não informado  não informado
# 26       09/11/2022  não informado  não informado
# 27       09/11/2022  não informado  não informado
# 28       08/11/2022  não informado  não informado
# 29       09/11/2022  não informado  não informado
# 30       08/11/2022  não informado  não informado
# 31       11/01/2023     08/02/2023     08/02/2024
# 32       20/01/2023     08/02/2023     08/02/2024
# 33       12/01/2023     08/02/2023     08/02/2024
# 34       11/01/2023     08/02/2023     08/02/2024
# 35       16/01/2023     08/02/2023     08/02/2024
# 36       18/01/2023     08/02/2023     08/02/2024
# 37  NÃO CONSTA DATA     08/02/2023     08/02/2024
# 38       19/01/2023     08/02/2023     08/02/2024
# 39       12/01/2023     08/02/2023     08/02/2024
# 40  NÃO CONSTA DATA     08/02/2023     08/02/2024
# 41       20/06/2023     21/08/2023     21/08/2024
# 42       20/06/2023     21/08/2023     21/08/2024
# 43       20/06/2023     21/08/2023     21/08/2024
# 44       26/06/2023     21/08/2023     21/08/2024

# %%
# Tratamento dos dados

# Tratando valores numéricos
arquivo['valor'] = arquivo['valor'].apply(lambda x: x.replace('R$ ', ''))
arquivo['valor'] = arquivo['valor'].apply(lambda x: x.replace('.', ''))
arquivo['valor'] = arquivo['valor'].astype(float)

# Tratando as datas
arquivo['fim_vigencia'] = arquivo['fim_vigencia'].apply(lambda x: x if x != 'não informado' else '')
arquivo['fim_vigencia'] = pd.to_datetime(arquivo['fim_vigencia'], format="mixed")
arquivo['fim_vigencia'] = arquivo['fim_vigencia'] + pd.DateOffset(years=1)

arquivo['inicio_vigencia'] = arquivo['inicio_vigencia'].apply(lambda x: x if x != 'NÃO CONSTA DATA' else None)
arquivo['inicio_vigencia'] = pd.to_datetime(arquivo['inicio_vigencia'], format="mixed")

# Removendo colunas desnecessárias
arquivo = arquivo[['pregão', 'ano', 'número', 'cpf_cnpj', 'fornecedor', 'objeto', 'valor', 'assinatura', 'inicio_vigencia', 'fim_vigencia']]

# %% [markdown]
# ## Análise/Questionamento 1
#
# Contratos de Medicamentos Humanos com Valor Superior a R$ 20.000 em 2023

# %%
# Filtragem dos dados
dados_filtrados = arquivo.loc[
    (arquivo['objeto'] == 'MEDICAMENTO HUMANO') \
    & (arquivo['ano'] == 2023) \
    & (arquivo['valor'] >= 20000)
]

# Exportação dos dados
dados_filtrados.to_csv('analise_1.csv', index=False)
upload_to_s3('analise_1.csv', 'desafio-compass-pb', 'resposta/analise_1.csv')
# Out:
# File 'analise_1.csv' uploaded to 'resposta/analise_1.csv' in bucket 'desafio-compass-pb'.
# True

# %% [markdown]
# ## Análise/Questionamento 2
#
# Valor Total de Contratos por Tipo de Objeto e Duração Média da Vigência

# %%
# Calcular duração da vigência em dias
arquivo['duracao_vigencia'] = (arquivo['fim_vigencia'] - arquivo['inicio_vigencia']).dt.days

# Agregar valor total por objeto e duração média
analise = arquivo.groupby('objeto').agg(
    valor_total=('valor', 'sum'),
    duracao_media=('duracao_vigencia', 'mean')
).reset_index()

# Exportação dos dados
analise.to_csv('analise_2.csv', index=False)
upload_to_s3('analise_1.csv', 'desafio-compass-pb', 'resposta/analise_2.csv')
# Out:
# File 'analise_1.csv' uploaded to 'resposta/analise_2.csv' in bucket 'desafio-compass-pb'.
# True

# %% [markdown]
# ## Análise/Questionamento 3
#
# Classificar Fornecedores "LTDA" com Base no Valor do Contrato

# %%
# Classificar valores em categorias
categorias = ['Baixo', 'Médio', 'Alto']

arquivo['categoria_valor'] = pd.cut(arquivo['valor'], bins=[0, 50000, 100000, float('inf')], labels=categorias)

# Filtrando apenas os fornecedores LTDA
empresas_ltda = arquivo.loc[arquivo['fornecedor'].str.contains('LTDA')]
empresas_ltda = empresas_ltda[['fornecedor', 'valor', 'categoria_valor']]

# Exportação dos dados
empresas_ltda.to_csv('analise_3.csv', index=False)
upload_to_s3('analise_1.csv', 'desafio-compass-pb', 'resposta/analise_3.csv')
# Out:
# File 'analise_1.csv' uploaded to 'resposta/analise_3.csv' in bucket 'desafio-compass-pb'.
# True
